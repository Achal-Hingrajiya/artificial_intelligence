# %% [markdown]
# <a href="https://colab.research.google.com/github/Achal-Hingrajiya/artificial_intelligence/blob/main/exploratory_data_analysis_of_students_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aquiring Data
# In this section we will extract data from university website usign web scrapping library BeautifulSoup and save it into local drive as a csv file.

# %% [markdown]
# ## Importing required libraries

# %%
import requests  # For requesting webpage
from bs4 import BeautifulSoup  # For webscrapping
import pandas as pd  # For manuplating DataFrames
import numpy as np  # For doing numerical computations
import threading  # For doing multithreding

# %% [markdown]
# ## Defining request parameters
# *   These parameters are stored as a hidden fields in the webpage sent together with the http request as a payload in order to get the result.
# *   These parameters are unique for tuple(Institute, Degree, Semester, ScheduleExam).

# %% [markdown]
# ### Defining request parameters for IT branch

# %%
sem1_it = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 2,
  "ddlSem": 1,
  "ddlScheduleExam": 7129,
  "txtEnrNo": 1,
  "btnSearch": "Show Marksheet"}

sem2_it = {
  "__VIEWSTATE": "...",
"__VIEWSTATEGENERATOR": "12BA245B",
"__EVENTVALIDATION": "...",
"ddlInst": 1,
"ddlDegree": 2,
"ddlSem": 2,
"ddlScheduleExam": 7847,
"txtEnrNo": 1,
"btnSearch":"Show Marksheet"
}

sem3_it = {
  "__VIEWSTATE": "...",
"__VIEWSTATEGENERATOR": "12BA245B",
"__EVENTVALIDATION": "...",
"ddlInst": 1,
"ddlDegree": 2,
"ddlSem": 3,
"ddlScheduleExam": 8786,
"txtEnrNo": 19012021012,
"btnSearch": "Show Marksheet"
}

sem4_it = {
  "__VIEWSTATE": "...",
"__VIEWSTATEGENERATOR": "12BA245B",
"__EVENTVALIDATION": "...",
"ddlInst": 1,
"ddlDegree": 2,
"ddlSem": 4,
"ddlScheduleExam": 9392,
"txtEnrNo": 19012021012,
"btnSearch": "Show Marksheet"
}

sem5_it = {
  "__VIEWSTATE": "...",
"__VIEWSTATEGENERATOR": "12BA245B",
"__EVENTVALIDATION": "...",
"ddlInst": 1,
"ddlDegree": 2,
"ddlSem": 5,
"ddlScheduleExam": 10385,
"txtEnrNo": 19012021012,
"btnSearch": "Show Marksheet"
}


sem6_it = {
    "__VIEWSTATE" : "...",
    "__VIEWSTATEGENERATOR" : "12BA245B",
    "__EVENTVALIDATION" : "...",
    "ddlInst": 1,
    "ddlDegree": 2,
    "ddlSem": 6,
    "ddlScheduleExam": 10783,
    "txtEnrNo": 19012021012,
    "btnSearch": "Show Marksheet"
}

# %% [markdown]
# ### Defining request parameters for CE branch

# %%
sem1_ce = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 1,
  "ddlSem": 1,
  "ddlScheduleExam": 7068,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}



sem2_ce = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 1,
  "ddlSem": 2,
  "ddlScheduleExam": 7846,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}


sem3_ce = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 1,
  "ddlSem": 3,
  "ddlScheduleExam": 8785,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem4_ce = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 1,
  "ddlSem": 4,
  "ddlScheduleExam": 9376,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem5_ce = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 1,
  "ddlSem": 5,
  "ddlScheduleExam": 10379,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem6_ce = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 1,
  "ddlSem": 6,
  "ddlScheduleExam": 10780,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

# %% [markdown]
# ### Defining request parameters for CE-AI branch

# %%
sem1_ce_ai = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 239,
  "ddlSem": 1,
  "ddlScheduleExam": 7680,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem2_ce_ai = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 239,
  "ddlSem": 2,
  "ddlScheduleExam": 7893,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem3_ce_ai = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 239,
  "ddlSem": 3,
  "ddlScheduleExam": 8783,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem4_ce_ai = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 239,
  "ddlSem": 4,
  "ddlScheduleExam": 9379,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem5_ce_ai = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 239,
  "ddlSem": 5,
  "ddlScheduleExam": 10425,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

sem6_ce_ai = {
  "__VIEWSTATE": "...",
  "__VIEWSTATEGENERATOR": "12BA245B",
  "__EVENTVALIDATION": "...",
  "ddlInst": 1,
  "ddlDegree": 239,
  "ddlSem": 6,
  "ddlScheduleExam": 10803,
  "txtEnrNo": 19012011001,
  "btnSearch": "Show Marksheet"
}

# %% [markdown]
# ### Associating previously defined request parameters and range of enrollments numbers to branch names.

# %%
# d2d_it = [20012012001, 20012012009]

branch_wise_enrollment_nos = {
    "ce" : {
        "enrollment_no" : [19012011001, 19012011150],
        "semester" : [sem1_ce, sem2_ce, sem3_ce, sem4_ce, sem5_ce, sem6_ce]
    },
     "ce_ai" : {
        "enrollment_no" : [19012531001, 19012531021],
        "semester" : [sem1_ce_ai, sem2_ce_ai, sem3_ce_ai, sem4_ce_ai, sem5_ce_ai, sem6_ce_ai]
    },

    "d2d" : {
        "enrollment_no" : [20012012001, 20012012049],
        "semester" : [sem3_ce, sem4_ce, sem5_ce, sem6_ce]
    },

    "it" : {
        "enrollment_no" : [19012021001, 19012021107],
        "semester" : [sem1_it, sem2_it, sem3_it, sem4_it, sem5_it, sem6_it]
    },    
}

# %% [markdown]
# ## Generating payloads
# *   We are generating payload for all students by iterating through all enrollment numbers of each branch, each semesters.

# %%
student_data = list()
for key, val in branch_wise_enrollment_nos.items():
  enrollment_no_range = val["enrollment_no"]
  semesters = val["semester"]
  for sem_data in semesters:
    for en_no in range(enrollment_no_range[0], enrollment_no_range[1] + 1):
      d = sem_data.copy()
      d["txtEnrNo"] = en_no
      student_data.append(d)

# %%
# Will be used to store dictionaries consisting of enrollemnt_no, program, istitute, branch
student_info_table = []  

# Will be used to store dictionaries consisting of enrollemnt_no, semester, month_and_year_of_exam, course_title, course_credit_earned, course_grade_earned, grade_points_earned, credit_points_earned
student_result_subject_wise_table = []  

# Will be used to store dictionaries consisting of enrollemnt_no, semester, month_and_year_of_exam, current_sem_credits_offered, current_sem_credits_earned, current_sem_grade_points_earned, current_sem_credit_points_earned, SGPA, current_sem_backlog, progressive_credits_offered, progressive_credits_earned, progressive_grade_points_earned. progressive_credit_points_earned, CGPA, progressive_backlog, 
student_overall_result_table = []  

# Will be used to store info about students when there is some issue with the result 
invalid_enrollment_nos = set()

# %% [markdown]
# ## Scrapping the data from the website

# %% [markdown]
# ### Defining function to request and parse data from website

# %%
# defining url of university website
url = 'https://result.ganpatuniversity.ac.in/'

# Function to do fetch data form website and store into lists defined erlier 
def fetch_student_result(d):

  # Making a post request to the url specified with the payload d
  x = requests.post(url, data = d)

  # Parsing the HTML response using BeautifulSoup
  soup = BeautifulSoup(x.text, "html.parser")

  # Finding the program in which student was enrolled
  program = soup.find(id="uclGrd_lblProgramme")

  # If there is no program mentioned in the page, which means there is no result declaed for that student.
  # We will ignore this student and add their data in invalid_enrollment_nos set
  
  if program is None:
    print("Program is none: ", d["txtEnrNo"])
    invalid_enrollment_nos.add(d["txtEnrNo"])
    return

  else:
    program = program.text.strip()

  res = soup.find(id="uclGrd_lblResult").text.strip()

  # If the result is WITHHELD, we will no longer prosess that student's result
  if res == "WITHHELD":
    print("Withheld: ", d["txtEnrNo"])
    invalid_enrollment_nos.add(d["txtEnrNo"])
    return
    
  # Finding all other required details from the webpage
  institute_name = soup.find(id="uclGrd_lblInstituteName").text.strip() 
  name = soup.find(id="uclGrd_lblStudentName").text.strip() 

  try:
    en_no = int(soup.find(id="uclGrd_lblExamNo").text.strip()) 
    degree_name = soup.find(id="uclGrd_lblDegreeName").text.strip() 
    semester = soup.find(id="uclGrd_lblSemester").text.strip()
    month_and_year_of_exam = soup.find(id="uclGrd_lblMnthYr").text.strip()
    sem_credits_offered = float(soup.find(id="uclGrd_lblCrdOffered").text.strip())
    sem_credits_earned = float(soup.find(id="uclGrd_lblCrdEarned").text.strip())
    sem_grade_points_earned = float(soup.find(id="uclGrd_lblGrdPtEarned").text.strip())
    sem_credit_points_earned = float(soup.find(id="uclGrd_lblCrdPtEarned").text.strip())
    sem_sgpa = float(soup.find(id="uclGrd_lblSGPA").text.strip())
    sem_backlog = int(soup.find(id="uclGrd_lblBacklog").text.strip())

    pro_credits_offered = float(soup.find(id="uclGrd_lblPrgCrdOffered").text.strip())
    pro_credits_earned = float(soup.find(id="uclGrd_lblPrgCrdEarned").text.strip())
    pro_grade_points_earned = float(soup.find(id="uclGrd_lblPrgGrdPtEarned").text.strip())
    pro_credit_points_earned = float(soup.find(id="uclGrd_lblPrgCrdPtEarned").text.strip())
    pro_cgpa = float(soup.find(id="uclGrd_lblPrgCGPA").text.strip())
    pro_backlog = int(soup.find(id="uclGrd_lblPrgBacklog").text.strip())
    effective_backlog = int(soup.find(id="uclGrd_lblEffBackLog").text.strip())
    
    # Fetching all rows present in results table
    # These rows will be containing subjectwise results of the student
    rows = soup.find(id="uclGrd_grdResult").find_all('tr')[1:]

    # Now, we will iterate through all rows and extract results of each subject
    for r in rows:
      cols = r.find_all('td')
      subject = cols[0].text.strip()
      course_credit_earned = float(cols[1].text.strip())
      course_grade_earned = cols[2].text.strip()
      grade_points_earned = float(cols[3].text.strip())
      credit_points_earned = float(cols[4].text.strip())
      # d = {"course_title": subject, "course_credit_earned":course_credit_earned, "course_grade_earned" : course_grade_earned, "grade_points_earned": grade_points_earned, 
      #      "credit_points_earned":credit_points_earned,  "en_no" : en_no ,"sem": semester, "month_and_year_of_exam":month_and_year_of_exam,}
      # result.append(d)

      # Storing extracted data in student_result_subjectwise list
      student_result_subjectwise = {"semester" :semester, "enrollment_no" : en_no, "month_and_year_of_exam" : month_and_year_of_exam,\
                                    "course_title" : subject, "course_credit_earned":course_credit_earned, "course_grade_earned" : course_grade_earned, \
                                    "grade_points_earned": grade_points_earned,     "credit_points_earned":credit_points_earned, }

      student_result_subject_wise_table.append(student_result_subjectwise)
    

    # curr_sem_progress = {"credits_offered":sem_credits_offered, "credits_earned" : sem_credits_earned, "grade_points_earned" : sem_grade_points_earned, 
    #                      "credit_points_earned" : sem_credit_points_earned, "SGPA" : sem_sgpa, "backlog" : sem_backlog}

    # progressive_performance = {"credits_offered":pro_credits_offered, "credits_earned" : pro_credits_earned, "grade_points_earned" : pro_grade_points_earned, 
    #                            "credit_points_earned" : pro_credit_points_earned, "CGPA" : pro_cgpa, "backlog" : pro_backlog}


    # Storing extracted data in student_overall_result list
    student_overall_result = {"semester" :semester, "enrollment_no" : en_no, "month_and_year_of_exam" : month_and_year_of_exam,\
                              "current_sem_credits_offered":sem_credits_offered, "current_sem_credits_earned" : sem_credits_earned, 
                              "current_sem_grade_points_earned" : sem_grade_points_earned, "current_sem_credit_points_earned" : sem_credit_points_earned, \
                              "SGPA" : sem_sgpa, "current_sem_backlog" : sem_backlog, "progressive_credits_offered":pro_credits_offered, \
                              "progressive_credits_earned" : pro_credits_earned, "progressive_grade_points_earned" : pro_grade_points_earned,\
                              "progressive_credit_points_earned" : pro_credit_points_earned, "CGPA" : pro_cgpa, "progressive_backlog" : pro_backlog
                        }
    student_overall_result_table.append(student_overall_result)

    # Printing the debug message
    print(f"Sem: {semester} Branch: {degree_name} Name: {name} CGPA: {sem_sgpa}")

    # data = {
    #     "name" : name, "institute_name" : institute_name, "en_no" : en_no, "degree_name" : degree_name, "sem": semester, "month_and_year_of_exam":month_and_year_of_exam,
    #     "curr_sem_progress":curr_sem_progress, "progressive_performance" :progressive_performance, "effective_backlog" : effective_backlog,
    #     "result" : result
    # }

    # Storing extracted data in student_info list
    student_info = {"program" : program, "institute_name" : institute_name, "enrollment_no" : en_no, "branch" : degree_name}
    student_info_table.append(student_info)

  except: 

    # Printing debug message if anything goes wrong while parsing the data
    print("Error while parsing values: ", d["txtEnrNo"])

# %% [markdown]
# ### Implementing multithreding to boost up the webscrappipng process

# %%
# Defining list of threads
threads = []

# We will be creating a new thread for fetchin each student's result
for d in student_data:
  threads.append(threading.Thread(target=fetch_student_result, args=(d,)))

# Starting all thread
for thread in threads:
  thread.start()

# Joining all threads
for thread in threads:
  thread.join()

print("Result complete")
# Out:
# Sem: I Branch: COMPUTER ENGINEERING Name: DAVE HARSHAL JANARDAN CGPA: 7.1
# Sem: I Branch: COMPUTER ENGINEERING Name: BHAVSAR VATSAL CHIRAGKUMAR CGPA: 6.05
# Sem: I Branch: COMPUTER ENGINEERING Name: DESAI SHYAM BHUPENDRA CGPA: 7.05
# Sem: I Branch: COMPUTER ENGINEERING Name: DHAKATE  HARSH NILESHBHAI CGPA: 8.25
# Sem: I Branch: COMPUTER ENGINEERING Name: CHHODVADIYA KISHAN MANSUKHBHAI CGPA: 6.5
# Sem: I Branch: COMPUTER ENGINEERING Name: PATEL AAYUSH SURESHBHAI CGPA: 7.75
# Sem: I Branch: COMPUTER ENGINEERING Name: BHADJA JENILKUMAR BHARATBHAI CGPA: 7.55
# Sem: I Branch: COMPUTER ENGINEERING Name: PARMAR CHINTANSINH ARVINDSINH CGPA: 7.45
# Sem: I Branch: COMPUTER ENGINEERING Name: PARMAR HIRABHAI GOVINDBHAI CGPA: 6.65
# Sem: I Branch: COMPUTER ENGINEERING Name: MEHTA YATRIK SAMIRKUMAR CGPA: 7.5
# Sem: I Branch: COMPUTER ENGINEERING Name: MAVANI HEET JINESH CGPA: 6.25
# Sem: I Branch: COMPUTER ENGINEERING Name: PATEL SMIT CHINUBHAI CGPA: 3.0
# ...

# %%
# Creating the dataFrame for student_info tabel
student_info_df = pd.DataFrame(data = student_info_table)
student_info_df.set_index("enrollment_no", inplace = True)
student_info_df = (student_info_df.reset_index().drop_duplicates(subset='enrollment_no', keep='last').set_index('enrollment_no').sort_index())
student_info_df.shape
# Out:
# (312, 3)

# %%
# Creating the dataFrame for student_info tabel
student_result_subject_wise_df = pd.DataFrame(data = student_result_subject_wise_table)
student_result_subject_wise_df.set_index("enrollment_no", inplace = True)
student_result_subject_wise_df.shape
# Out:
# (17804, 7)

# %%
# Creating the dataFrame for student_overall_result tabel
student_overall_result_df = pd.DataFrame(data = student_overall_result_table)
student_overall_result_df.set_index("enrollment_no", inplace = True)
student_overall_result_df.shape
# Out:
# (1714, 14)

# %%
# Creating csv files from the Data frames
student_info_df.to_csv("result_student_info.csv")
student_result_subject_wise_df.to_csv("student_result_subject_wise.csv")
student_overall_result_df.to_csv("student_overall_result.csv")

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Analyzing the result_student_info.csv file

# %%
# Reading the csv file
student_info_df = pd.read_csv("/content/result_student_info.csv", index_col = 0)

print(f"Shape of the dataframe: {student_info_df.shape}")
# Out:
# Shape of the dataframe: (312, 3)

# %% [markdown]
# This dataset is having 312 rows with 3 cols

# %% [markdown]
# ### Get preview of the data

# %%
student_info_df.head()
# Out:
#                               program                     institute_name  \
# enrollment_no
# 19012011001    BACHELOR OF TECHNOLOGY  U.V. PATEL COLLEGE OF ENGINEERING
# 19012011002    BACHELOR OF TECHNOLOGY  U.V. PATEL COLLEGE OF ENGINEERING
# 19012011003    BACHELOR OF TECHNOLOGY  U.V. PATEL COLLEGE OF ENGINEERING
# 19012011004    BACHELOR OF TECHNOLOGY  U.V. PATEL COLLEGE OF ENGINEERING
# 19012011005    BACHELOR OF TECHNOLOGY  U.V. PATEL COLLEGE OF ENGINEERING
#
#                              branch
# enrollment_no
# 19012011001    COMPUTER ENGINEERING
# 19012011002    COMPUTER ENGINEERING
# 19012011003    COMPUTER ENGINEERING
# 19012011004    COMPUTER ENGINEERING
# 19012011005    COMPUTER ENGINEERING

# %% [markdown]
# ### Get info about the data

# %%
student_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 19012011001 to 20012012049
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   program         312 non-null    object
#  1   institute_name  312 non-null    object
#  2   branch          312 non-null    object
# dtypes: object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# *  From the above cell we can observe that there are total **312** records having Integer index rangin from **19012011001 to 20012012049** with **3** data columns namely,
#         1. program
#         2. institute
#         3. branch
# *   All of 3 data columns haing 312 non-null values of type object(String), so there is no missing data in any records.
# *   This file used: 9.8+ KB of memory.

# %% [markdown]
# ### Get description about the data

# %%
student_info_df.describe()
# Out:
#                        program                     institute_name  \
# count                      312                                312
# unique                       1                                  1
# top     BACHELOR OF TECHNOLOGY  U.V. PATEL COLLEGE OF ENGINEERING
# freq                       312                                312
#
#                       branch
# count                    312
# unique                     3
# top     COMPUTER ENGINEERING
# freq                     188

# %% [markdown]
# From the abp
